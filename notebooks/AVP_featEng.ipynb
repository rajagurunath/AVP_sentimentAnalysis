# %%
import os
os.chdir("/content/gdrive/My Drive/AVP")

# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c41952f6ecdb> in <module>()
#       1 import os
# ----> 2 os.chdir("/content/gdrive/My Drive/AVP")
#       3
#       4 get_ipython().system('ls')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/AVP'
